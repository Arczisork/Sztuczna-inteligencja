# %% [markdown]
# <a href="https://colab.research.google.com/github/Arczisork/Sztuczna-inteligencja/blob/main/sztuczna_lab2_%C4%87w3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(tf.__version__)
# Out:
# 2.19.0

# %%
training_data = np.load('TF_dataset.npz')
input_size = 2
output_size = 1

# %%
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(5,activation="sigmoid"),
                             tf.keras.layers.Dense(5,activation="sigmoid"),
                             tf.keras.layers.Dense(output_size)
])
model.compile(optimizer='Adam',loss='Hinge')
model.fit(training_data['inputs'],training_data['targets'],epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 4.1169
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0545
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0451
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0393
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0348
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0308
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0272
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0239
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0212
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0189

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 0.9619628 ,  1.1197159 ,  0.01589465, -0.48020864, -0.6167619 ],
#         [-1.383148  , -1.6028287 , -0.10256158,  0.71742475,  0.36567152]],
#        dtype=float32),
#  array([0.37016943, 0.54936653, 0.39479992, 0.19318765, 0.11195049],
#        dtype=float32)]

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])),np.squeeze(training_data['targets']), color='orange')
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
