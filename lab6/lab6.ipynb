# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
import ollama

# %%
message = "Tell me something about transformer technology"
response = ollama.chat(model='llama3.2', messages=[{"role":"user", "content":message}])
print(response['message']['content'])
# Out:
# Transformer technology is a fascinating field that has revolutionized the way we transmit and distribute electricity. Here are some key aspects of transformer technology:
#
# 1. **Basic Principle**: A transformer is an electrical device that transfers electrical energy from one circuit to another through electromagnetic induction. It consists of two coils, known as primary and secondary coils, which are wound around a common core.
# 2. **Primary and Secondary Coils**: The primary coil receives the input electrical energy and induces a magnetic field in the core. This magnetic field then induces an electromotive force (EMF) in the secondary coil, which sends the output electrical energy to the load.
# 3. **Types of Transformers**: There are several types of transformers, including:
#  * Step-down transformers: Reduce the voltage of the input current.
#  * Step-up transformers: Increase the voltage of the input current.
#  * Isolation transformers: Provide electrical isolation between two circuits.
#  * Auto-transformers: Combine multiple coils in a single transformer.
# 4. **Advantages**: Transformers offer several advantages, including:
#  * Efficient energy transfer
#  * High power density
#  * Low losses (compared to traditional transmission lines)
#  * Ability to step up or step down voltage levels
# 5. **Materials and Cores**: The core of a transformer is typically made from magnetic materials such as iron, silicon steel, or ferrite. These materials are chosen for their high permeability, low loss, and ability to support the required magnetic field.
# 6. **Design and Construction**: Transformer design involves optimizing the ratio of turns in the primary and secondary coils, core material, and windings to minimize energy losses and achieve maximum efficiency.
# 7. **Applications**: Transformers have a wide range of applications, including:
#  * Power distribution systems
#  * Electric vehicles
#  * Renewable energy systems (e.g., solar, wind)
#  * Telecommunications equipment
# 8. **Innovations and Trends**: The development of new transformer technologies is ongoing, with recent advancements focusing on:
#  * High-voltage direct current (HVDC) transformers
#  * Low-loss materials and designs
#  * Hybrid transformers combining different coil configurations
# 9. **Future Prospects**: As the world transitions to renewable energy sources and increasing power demands, transformer technology will play a crucial role in meeting these challenges.
#
# Overall, transformer technology has come a long way since its invention, and its continued development is essential for efficient and reliable electrical power distribution.

# %%
# Niektóre strony internetowe wymagają użycia odpowiednich nagłówków podczas ich pobierania:
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

# Klasa reprezentująca stronę internetową, która zostanie pobrana do podsumowania.
class Website:
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        # Użyjemy biblioteki BeautifulSoup do zbudowania obiektu z treścią
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input", "link"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
web = Website("https://www.google.com/?hl=pl&zx=1778940680287")
print("Title: ", web.title)
print("text: ", web.text)
# Out:
# Title:  Google
# text:  Jeśli w ciągu kilku sekund nie nastąpi przekierowanie, kliknij
# tutaj
# .
# O nas
# Google Store
# Gmail
# Grafika
# Zaloguj się
# O czym myślisz?
# Get help with learning, planning,
# writing, and more
# Transform your ideas
# into images
# Prześlij obraz
# Prześlij plik
# Tryb AI
# Pokaż więcej
# Usuń
# Usuń
# Zgłoś nieodpowiednią podpowiedź
# Polska
# Reklamuj się
# Dla firm
# Jak działa wyszukiwarka
# Już 3 dekady działamy na rzecz klimatu: zobacz, co robimy
# Prywatność
# Warunki
# Ustawienia
# Ustawienia wyszukiwania
# Szukanie zaawansowane
# Twoje dane w wyszukiwarce
# Personalizacja i pliki cookie
# Historia wyszukiwania
# Pomoc dotycząca wyszukiwania
# Prześlij opinię
# Ciemny motyw: wyłączony
# pl
# ‪polski‬
# ‪Deutsch‬
# ‪English (United Kingdom)‬
# ‪Español (España)‬
# ‪Français (France)‬
# ‪Italiano‬
# Wszystkie języki
# ‪Afrikaans‬
# ‪azərbaycan‬
# ‪bosanski‬
# ‪català‬
# ‪Čeština‬
# ‪Cymraeg‬
# ‪Dansk‬
# ‪Deutsch‬
# ‪eesti‬
# ‪English (United Kingdom)‬
# ‪English (United States)‬
# ‪English‬
# ‪Español (España)‬
# ‪Español (Latinoamérica)‬
# ‪euskara‬
# ‪Filipino‬
# ‪Français (Canada)‬
# ‪Français (France)‬
# ‪Gaeilge‬
# ‪galego‬
# ‪Hrvatski‬
# ‪Indonesia‬
# ‪isiZulu‬
# ‪íslenska‬
# ‪Italiano‬
# ‪Kiswahili‬
# ‪latviešu‬
# ‪lietuvių‬
# ‪magyar‬
# ‪Melayu‬
# ‪Nederlands‬
# ‪norsk‬
# ‪o‘zbek‬
# ‪Português (Brasil)‬
# ‪Português (Portugal)‬
# ‪română‬
# ‪shqip‬
# ‪Slovenčina‬
# ‪slovenščina‬
# ‪srpski (latinica)‬
# ‪Suomi‬
# ‪Svenska‬
# ‪Tiếng Việt‬
# ‪Türkçe‬
# ‪Ελληνικά‬
# ‪беларуская‬
# ‪български‬
# ‪кыргызча‬
# ‪македонски‬
# ‪монгол‬
# ‪Русский‬
# ‪српски (ћирилица)‬
# ‪Українська‬
# ‪ქართული‬
# ‪қазақ тілі‬
# ‪հայերեն‬
# ‫עברית‬
# ‫اردو‬
# ‫العربية‬
# ‫فارسی‬
# ‪አማርኛ‬
# ‪नेपाली‬
# ‪मराठी‬
# ‪हिन्दी‬
# ‪বাংলা‬
# ‪ਪੰਜਾਬੀ‬
# ‪ગુજરાતી‬
# ‪தமிழ்‬
# ‪తెలుగు‬
# ‪ಕನ್ನಡ‬
# ‪മലയാളം‬
# ‪සිංහල‬
# ‪ไทย‬
# ‪ລາວ‬
# ‪မြန်မာ‬
# ‪ខ្មែរ‬
# ‪한국어‬
# ‪中文（香港）‬
# ‪日本語‬
# ‪简体中文‬
# ‪繁體中文‬
# Zaloguj się
# Zanim przejdziesz do Google
# Używamy
# plików cookie
# i innych danych do:
# Dostarczania i utrzymywania usług Google
# Śledzenia przerw w działaniu usług i ochrony użytkowników przed spamem, oszustwami i nadużyciami
# Pomiaru zaangażowania odbiorców oraz generowania statystyk dotyczących stron, aby lepiej zrozumieć, jak nasze usługi są używane, i aby poprawiać jakość tych usług
# Jeśli wybierzesz „Zaakceptuj wszystko”, będziemy używać plików cookie i innych danych także do:
# Opracowywania i udoskonalania nowych usług
# Wyświetlania reklam i mierzenia ich skuteczności
# Wyświetlania spersonalizowanych treści (w zależności od Twoich ustawień)
# Wyświetlania spersonalizowanych reklam (w zależności od Twoich ustawień)
# Jeśli wybierzesz „Odrzuć wszystko”, nie będziemy używać plików cookie w tych dodatkowych celach.
# Treści niespersonalizowane są dobierane na podstawie takich czynników jak aktualnie przeglądana treść, aktywność podczas bieżącej sesji w wyszukiwarce czy Twoja lokalizacja. Reklamy niespersonalizowane są wyświetlane na podstawie aktualnie przeglądanej treści oraz Twojej przybliżonej lokalizacji. Reklamy i treści spersonalizowane mogą dodatkowo zawierać trafniejsze wyniki, rekomendacje oraz lepiej dopasowane reklamy oparte na wcześniejszej aktywności w przeglądarce, np. wcześniejszych wyszukiwaniach w Google. W odpowiednich przypadkach używamy plików cookie i danych także do dostosowywania usług do wieku odbiorcy.
# Aby zobaczyć dodatkowe informacje, w tym szczegóły na temat zarządzania ustawieniami prywatności, wybierz „Więcej opcji”. W każdej chwili możesz też wejść na
# g.co/privacytools
# .
# Odrzuć wszystko
# Zaakceptuj wszystko
# Więcej opcji
# Prywatność
# ·
# Warunki
# Aplikacje Google

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown in Polish."

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
MODEL = 'llama3.2'
def summarize(url):
    website = Website(url)
    response = ollama.chat(
        model=MODEL,
        messages=messages_for(website)
    )
    return response['message']['content']

# %%
summarize("https://www.google.com/?hl=pl&zx=1778940680287")
# Out:
# '**Podsumowanie strony Google**\n\nStrona Google jest głównym strazon wirtualnym, który oferuje wiele usług i funkcjonalności. Oto podstawowa informacja o stronie:\n\n* **Usługi**: Google offre zróżne usługi, w tym wyszukiwarka, serwis e-mail (Gmail), platforma sprzedażi (Google Store) i wiele innych.\n* **Celem strony**: Celem strony jest dostarczenie informacji i usług dla użytkowników wirtualnym.\n* **Dane prywatności**: Strona używa plików cookie i danych do celów marketingowych, ale można je odmienić poprzez wybór "Odrzuć wszystko" albo "Zaakceptuj wszystko".\n* **Języki**: Strona jest dostępna w wielu językach, w tym polskim.\n* **Większe informacje**: Dodatkowe informacje na temat zarządzania ustawieniami prywatności i aplikacjami Google można znaleźć na stronie [g.co/privacytools](https://g.co/privacytools).\n\n**Aktualne ogłoszenia**\n\nBrak ogłoszeń lub aktualizacji na stronie.'

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.google.com/?hl=pl&zx=1778940680287")
# Out:
# **Podsumowanie strony Google**
#
# Google jest prywatną spółką z siedzibą w Kalifornii, USA. Spółka została założona w 1998 roku przez Larry'ego i Sergey'ego Brin'a oraz Erica Schmida.
#
# **Usługi Google**
#
# Google oferuje wiele usług, w tym:
#
# *   wyszukiwarka internetowa
# *   serwis e-mail (Gmail)
# *   platforma dla firm (Google for Business)
# *   Google Drive - narzędzie do przechowywania i zarządzania plikami
# *   YouTube - platformaideostrumieńcza
#
# **Prywatność**
#
# Strona Google informuje o tym, że używa plików cookie w celu dostarczania usług i personalizacji wyświetlanych treści. Użytkownicy mają możliwość zaakceptowania lub odmówienia akceptacji plików cookie.
#
# **Języki**
#
# Strona Google jest dostępna w wiele języków, w tym:
#
# *   angielskim
# *   hiszpańskim
# *   niemieckim
# *   rosyjskim
# *   francuskim
# *   włoskim
# *   polskim
#
# **Kontakt**
#
# Jeśli chcesz skontaktować się z Google, możesz dołożyć poniższe adresy:
#
# *   Adres e-mail: contact@google.com
# *   Telefon: (650) 253-0000
